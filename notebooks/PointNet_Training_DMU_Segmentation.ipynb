# %% [markdown]
# <a href="https://colab.research.google.com/github/dhirajsuvarna/pointnet.pytorch/blob/master/notebooks/PointNet_Training_DMU_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement PointNet on DMU-Dataset - Segmentation

# %% [markdown]
# ### Setup the google drive

# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/mydrive

# %%
cd /content/mydrive/My\ Drive/Projects/pointnet/pointnet.pytorch/
# Out:
# /content/mydrive/My Drive/Projects/pointnet/pointnet.pytorch

# %% [markdown]
# ### Update the Repository

# %%
#for the first time
#!git clone https://github.com/dhirajsuvarna/pointnet.pytorch.git
! git pull
# Out:
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 15), reused 19 (delta 9), pack-reused 0
# Unpacking objects: 100% (36/36), done.
# From https://github.com/dhirajsuvarna/pointnet.pytorch
#    7555d04..4db80f7  master     -> origin/master
# Updating 7555d04..4db80f7
# Fast-forward
#   notebooks/PointNet_Training_DMU.ipynb             | 7574 --------------------
#  .gitignore                                         |    1 +
#  dataset_utils/pcd_utils/create_seg_file.py         |   93 +
#  .../pcd_utils/create_train_test_shuffle.py         |  103 +-
#  notebooks/PointNet_DMU_Classification.ipynb        | 5618 +++++++++++++++
#  notebooks/PointNet_Training_DMU.ipynb              | 7531 -------------------
#  ... PointNet_Training_ShapeNet_Segmentation.ipynb} |   28 +-
#  pointnet/dataset.py                                |   66 +-
# ...

# %%
# !git config --global user.email "dhiraj.suvarna@gmail.com"

# %%
! git stash
# Out:
# Saved working directory and index state WIP on master: fd5a674 Merge branch 'master' of https://github.com/dhirajsuvarna/pointnet.pytorch

# %% [markdown]
# ### Uzip the dataset

# %%
cd /content/mydrive/My\ Drive/Projects/pointnet/dataset
# Out:
# /content/mydrive/My Drive/Projects/pointnet/dataset

# %%
# !unzip segmented_dataset_pcd_5000.zip

# %%
cd /content/mydrive/My\ Drive/Projects/pointnet/pointnet.pytorch
# Out:
# /content/mydrive/My Drive/Projects/pointnet/pointnet.pytorch

# %% [markdown]
# ### Try to get max GPU

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7413 sha256=8dd00f879db4783d97f015fce06cedbac1416865705d6f01127a98baa73f7f4d
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.8 GB  | Proc size: 158.5 MB
# GPU RAM Free: 15079MB | Used: 0MB | Util   0% | Total 15079MB

# %% [markdown]
# # Install the Python Pacakages

# %%
# !pip install plyfile

# %%
# !pip install open3d

# %% [markdown]
# ### Create Train Test Split

# %%
cd /content/mydrive/My\ Drive/Projects/pointnet/pointnet.pytorch/dataset_utils/pcd_utils
# Out:
# /content/mydrive/My Drive/Projects/pointnet/pointnet.pytorch/dataset_utils/pcd_utils

# %%
# !python create_train_test_shuffle.py --input /content/mydrive/My\ Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000 \
                                    --split_percent 80 \
                                    --ext .pcd
# Out:
# Arguments:Namespace(ext='.pcd', input='/content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000', labeled_split=False, split_percent=80)
# Creating split of : /content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000/screw

# %%
cd /content/mydrive/My\ Drive/Projects/pointnet/pointnet.pytorch
# Out:
# /content/mydrive/My Drive/Projects/pointnet/pointnet.pytorch

# %% [markdown]
# # Start Training

# %%
# !rm -r runs

# %%
# !rm -r saved_models

# %% [markdown]
# ### Running on Pre-exiting Dataset

# %%
# !python train_segmentation.py --nepoch 25 \
                                --batchSize 32 \
                                --dataset /content/mydrive/My\ Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000 \
                                --class_choice screw \
                                --dataset_type dmunet \
                                --num_points 4000
# Out:
# Namespace(batchSize=32, class_choice='screw', dataset='/content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000', dataset_type='dmunet', feature_transform=False, model='', nepoch=25, num_points=4000, outf='saved_models', workers=4)
# Random Seed:  1827
# #Training Examples: 140, #Testing Examples:36
# #classes: 2
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [0: 0/4] train loss: 0.793172 accuracy: 0.649775
# [0: 0/4] test loss: 0.688152 accuracy: 1.147100
# ...

# %%
# !python train_segmentation.py --nepoch 50 \
                                --batchSize 32 \
                                --dataset /content/mydrive/My\ Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000 \
                                --class_choice screw \
                                --dataset_type dmunet \
                                --num_points 4000
# Out:
# Namespace(batchSize=32, class_choice='screw', dataset='/content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000', dataset_type='dmunet', feature_transform=False, model='', nepoch=50, num_points=4000, outf='saved_models', workers=4)
# Random Seed:  5448
# #Training Examples: 140, #Testing Examples:36
# #classes: 2
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [0: 0/4] train loss: 0.698589 accuracy: 0.903863
# [0: 0/4] test loss: 0.679957 accuracy: 1.153337
# ...

# %%
# !python train_segmentation.py --nepoch 100 \
                                --batchSize 32 \
                                --dataset /content/mydrive/My\ Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000 \
                                --class_choice screw \
                                --dataset_type dmunet \
                                --num_points 4000
# Out:
# Namespace(batchSize=32, class_choice='screw', dataset='/content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000', dataset_type='dmunet', feature_transform=False, model='', nepoch=100, num_points=4000, outf='saved_models', workers=4)
# Random Seed:  461
# #Training Examples: 140, #Testing Examples:36
# #classes: 2
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [0: 0/4] train loss: 0.668084 accuracy: 0.969250
# [0: 0/4] test loss: 0.707188 accuracy: 0.445337
# ...

# %%
# !python train_segmentation.py --nepoch 200 \
                                --batchSize 32 \
                                --dataset /content/mydrive/My\ Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000 \
                                --class_choice screw \
                                --dataset_type dmunet \
                                --num_points 4000
# Out:
# Namespace(batchSize=32, class_choice='screw', dataset='/content/mydrive/My Drive/Projects/pointnet/dataset/segmented_dataset_pcd_5000', dataset_type='dmunet', feature_transform=False, model='', nepoch=200, num_points=4000, outf='saved_models', workers=4)
# Random Seed:  9649
# #Training Examples: 140, #Testing Examples:36
# #classes: 2
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [0: 0/4] train loss: 0.701765 accuracy: 0.835625
# [0: 0/4] test loss: 0.696078 accuracy: 0.443000
# ...
